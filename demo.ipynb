# %% [markdown]
# # CS 230 : Infer Demo

# %%
TO DO
- sections dedicated to theory/key utility (what's under the hood)
- cell for getting started?..describe capture/analysis phases, diff workflows
- cells to demo basic examples (high-level view)

there are SO many use cases listed under "Analyses and Issue Types"..can give a high-level view (table?)
of them and categorize them, and then dive into demos for the most interesting ones?
- checkers, issue types (table?)
- complexity/impact analysis
